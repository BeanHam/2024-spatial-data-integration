# %%
import numpy as np
import pandas as pd
import scienceplots
import seaborn as sns
import matplotlib.pyplot as plt

# %%
6440*0.15
# Out:
# 966.0

# %%
samples=[966, 1932, 3221, 4509, 6440]
acc=[0.805432, 0.841968, 0.907136, 0.940046, 0.958944]
heuristic=0.937765

# %%
plt.figure(figsize=(5,2))
plt.hlines(y=heuristic,xmin=950,xmax=6500, color='red',linestyle='--',label='Heuristic')
plt.plot(samples, acc,label='llama3')
plt.scatter(samples, acc)
plt.title('Spatial Join Accuracy',fontsize=14)
plt.xlabel('Fine-Tuning Sample Size', fontsize=12)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.legend(loc=4)
pass
